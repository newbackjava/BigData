# %% [markdown]
# <a href="https://colab.research.google.com/github/newbackjava/BigData/blob/master/data_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("환영해 구글.....")
# Out:
# 환영해 구글.....

# %%
# 쉬프트 + 엔터 : 현재 셀 실행하고 다음 셀을 생성함.

# %%
data = input("몇시에 끝나나요???")
data
# Out:
# 몇시에 끝나나요???7시
# '7시'

# %%
print("수정하자.!!!")
